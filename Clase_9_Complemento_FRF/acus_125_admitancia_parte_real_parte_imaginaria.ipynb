# %%
# %%HTML
# <!-- Mejorar visualización en proyector -->
# <style>
# .rendered_html {font-size: 1.2em; line-height: 150%;}
# div.prompt {min-width: 0ex; }
# .container {width:95% !important;}
# </style>
# Out:
# <!-- Mejorar visualización en proyector -->
# <style>
# .rendered_html {font-size: 1.2em; line-height: 150%;}
# div.prompt {min-width: 0ex; }
# .container {width:95% !important;}
# </style>

# %% [markdown]
# <h1 style="text-align:center">Clase 9: Complemento de vibración forzada y funciones de transferencia</h1>
# <h3 style="text-align:center">ACUS125: Aislamiento y Análisis de Vibraciones</h3>
# <p style="text-align:center">Dr. Víctor Poblete <br>
# <a href="mailto:vpoblete@uach.cl">vpoblete@uach.cl</a><br>
# <a href="https://github.com/vpobleteacustica/ACUS125-Aislamiento-y-Analisis-de-Vibraciones">https://github.com/vpobleteacustica/ACUS125-Aislamiento-y-Analisis-de-Vibraciones</a><br>
# <a href="http://www.acusticauach.cl">www.acusticauach.cl</a><br>

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import EngFormatter

# %% [markdown]
# <p style="text-align:center">
# 	<img src="algebra.jpg" alt="MDOF" width=25%/></a><br>
#     <strong> Figura 1: Desarrollo algebraico.</strong>
# </p>

# %% [markdown]
# #### Implementación en Python usando los siguientes datos:

# %%
m   = 1               # masa 1 kg
f0  = 100             # frecuencia natural f0= 100 Hz  ( w0 = 628.32 rad/s )
w0  = f0 * 2 * np.pi  # a rad/s
k   = m*w0**2 # rigidez k = 3.948e+05 N/m
w   = np.logspace(0,4,5000)
z   = 0.05

# %% [markdown]
# #### Función admitancia: Parte real y parte imaginaria:

# %%
Re_X_F  = (w0**2/k)*(w0**2-w**2)/((w0**2-w**2)**2+(2*z*w0*w)**2)     # parte real
Im_X_F  = -(w0**2/k)*(2*z*w0*w)/((w0**2 - w**2)**2 + (2*z *w0*w)**2) # parte imag

# %% [markdown]
# #### Ploteamos parte real versus parte imaginaria:

# %%
fig = plt.figure(figsize=(8, 5))
ax = plt.gca()

plt.subplots_adjust(bottom = 0.1    , left = 0.1     , top = 0.96, right = 0.96)
plt.setp(ax.get_ymajorticklabels(), family = 'nunito', fontsize = 16)
plt.setp(ax.get_xmajorticklabels(), family = 'nunito', fontsize = 16)
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.grid(True, linestyle='--', color='0.5')
ax.set_axisbelow(True)
ax.plot(Re_X_F, Im_X_F,'o',linewidth = 3.0,label='z = '+str(z))
plt.grid(True,which="both",ls="--")
    
ax.set_xlabel('Parte Real',family='nunito', fontsize=16, weight='bold', labelpad=10)
ax.set_ylabel('Parte Imaginaria', color='k',family='nunito', fontsize=16, weight='bold', labelpad=10)
plt.legend()
plt.show()
# Out:
# findfont: Font family ['nunito'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['nunito'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #### Ploteamos parte real versus frecuencia:

# %%
fig = plt.figure(figsize=(8, 5))
ax = plt.gca()

plt.subplots_adjust(bottom = 0.1    , left = 0.1     , top = 0.96, right = 0.96)
plt.setp(ax.get_ymajorticklabels(), family = 'nunito', fontsize = 16)
plt.setp(ax.get_xmajorticklabels(), family = 'nunito', fontsize = 16)
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.grid(True, linestyle='--', color='0.5')
ax.set_axisbelow(True)
ax.semilogx(w/(2*np.pi), Re_X_F,linewidth = 3.0,label='z = '+str(z))
plt.grid(True,which="both",ls="--")
formatter0 = EngFormatter(unit='Hz')
ax.xaxis.set_major_formatter(formatter0)
ax.set_xlim([1,1000])
ax.set_xlabel('Frecuencia de excitación',family='nunito', fontsize=16, weight='bold', labelpad=10)
ax.set_ylabel('Parte Real', color='k',family='nunito', fontsize=16, weight='bold', labelpad=10)
plt.legend()
plt.show()

# %% [markdown]
# #### Ploteamos parte imaginaria versus frecuencia:

# %%
fig = plt.figure(figsize=(8, 5))
ax = plt.gca()

plt.subplots_adjust(bottom = 0.1    , left = 0.1     , top = 0.96, right = 0.96)
plt.setp(ax.get_ymajorticklabels(), family = 'nunito', fontsize = 16)
plt.setp(ax.get_xmajorticklabels(), family = 'nunito', fontsize = 16)
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.grid(True, linestyle='--', color='0.5')
ax.set_axisbelow(True)
ax.semilogx(w/(2*np.pi), Im_X_F,linewidth = 3.0,label='z = '+str(z))
plt.grid(True,which="both",ls="--")
formatter0 = EngFormatter(unit='Hz')
ax.xaxis.set_major_formatter(formatter0)
ax.set_xlim([1,1000])
ax.set_xlabel('Frecuencia de excitación',family='nunito', fontsize=16, weight='bold', labelpad=10)
ax.set_ylabel('Parte Imaginaria', color='k',family='nunito', fontsize=16, weight='bold', labelpad=10)
plt.legend()
plt.show()

# %% [markdown]
# #### Pueden revisar el siguiente documento páginas 44 y 45, Figuras 3.7 y 3.8, interpretación en 3D:
# > + https://moodle2.units.it/pluginfile.php/75129/mod_resource/content/1/EMA.pdf
